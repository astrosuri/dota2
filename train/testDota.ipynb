# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hero_data = pd.read_csv("./hero_data.csv")

# %%
hero_data
# Out:
#      hero_id primary_attr attack_type  \
# 0          1          agi       Melee
# 1          2          str       Melee
# 2          3          int      Ranged
# 3          4          agi       Melee
# 4          5          int      Ranged
# ..       ...          ...         ...
# 110      112          int      Ranged
# 111      113          agi      Ranged
# 112      114          agi       Melee
# 113      119          int      Ranged
# 114      120          agi       Melee
#
#                                              roles  base_health  \
# 0                               Carry:Escape:Nuker          200
# 1               Initiator:Durable:Disabler:Jungler          200
# 2                   Support:Disabler:Nuker:Durable          200
# 3           Carry:Disabler:Jungler:Nuker:Initiator          200
# 4                   Support:Disabler:Nuker:Jungler          200
# ..                                             ...          ...
# ...

# %%
train9_data = pd.read_csv("./train9.csv")

# %%
train9_data
# Out:
#        user_id  hero_id        id  num_games  num_wins    kda_ratio
# 0            1       74      1_74        304       185  3743.699732
# 1            1       65      1_65        255       151  4009.021513
# 2            1       39      1_39        203       135  5094.621514
# 3            1      106     1_106        158       106  4619.212963
# 4            1        2       1_2        157        94  2871.627907
# ...        ...      ...       ...        ...       ...          ...
# 18841     2992        8    2992_8         97        59  4153.992395
# 18842     2992       34   2992_34         93        40  3571.428572
# 18843     2992       70   2992_70         89        53  4212.180747
# 18844     2992       76   2992_76        290       211  5471.003135
# 18845     2992      114  2992_114         89        58  4396.396396
#
# [18846 rows x 6 columns]
